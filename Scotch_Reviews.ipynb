# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/RJ/OneDrive/Dataset/scotch_review/scotch_review.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                             name  \
# 0           1                   Johnnie Walker Blue Label, 40%
# 1           2  Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 2           3      Bowmore 46 year old (distilled 1964), 42.9%
# 3           4                   Compass Box The General, 53.4%
# 4           5                          Chivas Regal Ultis, 40%
#
#                      category  review.point     price currency  \
# 0       Blended Scotch Whisky            97       225        $
# 1          Single Malt Scotch            97   4500.00        $
# 2          Single Malt Scotch            97  13500.00        $
# 3  Blended Malt Scotch Whisky            96       325        $
# 4  Blended Malt Scotch Whisky            96       160        $
#
#                                          description
# 0  Magnificently powerful and intense. Caramels, ...
# 1  What impresses me most is how this whisky evol...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'category', 'review.point', 'price', 'currency',
#        'description'],
#       dtype='object')

# %% [markdown]
# <h1>Missing Data</h1>
# <br>
# Checking data to determine whether each column has complete data.  If there missing data was present it would be represented as an yellow line.
# <br><br>
# No missing data is present in this dataset.

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %% [markdown]
# <h1> Price Points </h1>

# %%
df['price'].value_counts()
# Out:
# 100         44
# 70.00       42
# 65.00       41
# 80.00       41
# 100.00      41
# 60.00       36
# 50.00       29
# 75.00       24
# 150.00      23
# 65          23
# 125.00      23
# 200.00      23
# 85.00       22
# 55.00       22
# 120.00      21
# 80          20
# 60          20
# 90.00       20
# 300.00      18
# 130.00      18
# 45.00       18
# 40.00       17
# 110         17
# 70          17
# 140         16
# 160.00      16
# 130         16
# 160         16
# 110.00      15
# 135         15
#             ..
# 3657.00      1
# 146          1
# 131          1
# 690          1
# 24000.00     1
# 5730.00      1
# 294.00       1
# 390          1
# 215          1
# 330.00       1
# 383          1
# 174.00       1
# 310          1
# 116          1
# 161          1
# 694.00       1
# 625          1
# 207          1
# 21000.00     1
# 261.00       1
# 587          1
# 2525.00      1
# 557          1
# 139          1
# 294          1
# 263.00       1
# 132          1
# ...

# %% [markdown]
# <h2>Top 10 Price Points</h2>

# %%
df['price'].value_counts()[:10]
# Out:
# 100       44
# 70.00     42
# 65.00     41
# 80.00     41
# 100.00    41
# 60.00     36
# 50.00     29
# 75.00     24
# 150.00    23
# 65        23
# Name: price, dtype: int64

# %%
df['price'].value_counts()[:10].plot(kind='barh')

# %%
df.price
# Out:
# 0                          225
# 1                      4500.00
# 2                     13500.00
# 3                          325
# 4                          160
# 5                        85.00
# 6                      6250.00
# 7                     11000.00
# 8                      1500.00
# 9                         3360
# 10                      750.00
# 11                     1500.00
# 12                        3108
# 13                      105.00
# 14                         120
# 15                     3500.00
# 16                       70.00
# 17                    20000.00
# 18                       70.00
# 19      $15,000 or $60,000/set
# 20                       26650
# 21                      400.00
# 22                      200.00
# 23                      400.00
# 24                      455.00
# 25                         750
# 26                      200.00
# 27                      460.00
# 28                     2525.00
# 29                     1250.00
# ...

# %% [markdown]
# <h1>Types of Scotch</h1>

# %%
df['category'].value_counts()
# Out:
# Single Malt Scotch            1819
# Blended Scotch Whisky          211
# Blended Malt Scotch Whisky     132
# Single Grain Whisky             57
# Grain Scotch Whisky             28
# Name: category, dtype: int64

# %%
df['category'].value_counts()[:3].plot(kind= 'barh')

# %%
df.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0                                               name  \
# 0              1                     Johnnie Walker Blue Label, 40%
# 1              2    Black Bowmore, 1964 vintage, 42 year old, 40.5%
# 2              3        Bowmore 46 year old (distilled 1964), 42.9%
# 3              4                     Compass Box The General, 53.4%
# 4              5                            Chivas Regal Ultis, 40%
# 5              6                         Ardbeg Corryvreckan, 57.1%
# 6              7                 Gold Bowmore, 1964 vintage, 42.4%
# 7              8                        Bowmore, 40 year old, 44.8%
# 8              9                    The Dalmore, 50 year old, 52.8%
# 9             10    Glenfarclas Family Casks 1954 Cask #1260, 47.2%
# 10            11  The Glenlivet Cellar Collection, 1969 vintage,...
# 11            12  Macallan 1976 Vintage, 29 year old, cask #1135...
# ...

# %%
df.price.unique
# Out:
# <bound method Series.unique of 0                          225
# 1                      4500.00
# 2                     13500.00
# 3                          325
# 4                          160
# 5                        85.00
# 6                      6250.00
# 7                     11000.00
# 8                      1500.00
# 9                         3360
# 10                      750.00
# 11                     1500.00
# 12                        3108
# 13                      105.00
# 14                         120
# 15                     3500.00
# 16                       70.00
# 17                    20000.00
# 18                       70.00
# 19      $15,000 or $60,000/set
# 20                       26650
# 21                      400.00
# 22                      200.00
# 23                      400.00
# 24                      455.00
# 25                         750
# 26                      200.00
# 27                      460.00
# 28                     2525.00
# ...

# %%
df.groupby('price').mean()
# Out:
#                          Unnamed: 0  review.point
# price
# $15,000 or $60,000/set    20.000000     95.000000
# 1,100                    201.333333     92.000000
# 1,400                    925.000000     88.000000
# 1,500.00                 609.000000     89.000000
# 1,700                    101.000000     93.000000
# 1,735                    302.000000     91.000000
# 100                     1062.590909     87.159091
# 100.00                   999.365854     87.414634
# 1000                     639.000000     89.500000
# 1000.00                  540.250000     90.250000
# 1008                    1630.000000     84.000000
# 101                     1638.111111     83.888889
# 101.00                  1060.666667     87.000000
# 1013                    1305.000000     86.000000
# 102                     1626.000000     83.500000
# 103                      376.000000     91.000000
# 103.00                  1209.333333     86.333333
# 104                     1382.666667     85.666667
# ...

# %%
demo=df.groupby(['name', 'review.point']).count()['price']
demo=demo.sort_values(ascending=False)
demo.head(10)
# Out:
# name                                                                                         review.point
# Arran 18 year old, 46%                                                                       89              2
# Chapter 7 (undisclosed Highland distillery), 55.8%                                           90              2
# Longmorn 16 year old, 48%                                                                    89              2
# Springbank, 18 year old, 46%                                                                 88              2
# Ledaig, 10 year old, 43%                                                                     80              2
# Bowmore, 18 year old, 43%                                                                    91              2
# Wemyss Malts (distilled at Clynelish) “A Day at the Coast” 14 year old, 46%                  85              2
# ...

# %%
sns.countplot('price', data=df)

# %%
df['category'].value_counts()[:3]
# Out:
# Single Malt Scotch            1819
# Blended Scotch Whisky          211
# Blended Malt Scotch Whisky     132
# Name: category, dtype: int64
